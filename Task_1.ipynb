# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pop = pd.read_csv('/content/drive/MyDrive/datasets/World Population.csv')

# %%
pop.dtypes
# Out:
# Rank                        int64
# Country (or dependency)    object
# Region                     object
# Population                  int64
# World Share                object
# dtype: object

# %%
pop.head(3)
# Out:
#    Rank Country (or dependency)    Region  Population World Share
# 0     1                   China      Asia  1411778724      18.47%
# 1     2                   India      Asia  1386141732      17.70%
# 2     3           United States  Americas   332960297       4.25%

# %%
pop.tail(3)
# Out:
#      Rank Country (or dependency)    Region  Population World Share
# 232   233                    Niue  Americas        5000       0.00%
# 233   234                 Tokelau  Americas        4000       0.00%
# 234   235                Holy See   Oceania        1966       0.00%

# %%
pop.head(3)
# Out:
#    Rank Country (or dependency)    Region  Population World Share
# 0     1                   China      Asia  1411778724      18.47%
# 1     2                   India      Asia  1386141732      17.70%
# 2     3           United States  Americas   332960297       4.25%

# %%
pop.tail(3)
# Out:
#      Rank Country (or dependency)    Region  Population World Share
# 232   233                    Niue  Americas        5000       0.00%
# 233   234                 Tokelau  Americas        4000       0.00%
# 234   235                Holy See   Oceania        1966       0.00%

# %%
sns.histplot(y='Region',hue='Region',data=pop)
# Out:
# <Axes: xlabel='Count', ylabel='Region'>

# %%
piepop = pop[0:10]

# %%
piepop['Population'].mean()
# Out:
# 449711022.9

# %%
sns.barplot(x="Population", y="Country (or dependency)",  hue="World Share", data = piepop)
# Out:
# <Axes: xlabel='Population', ylabel='Country (or dependency)'>
