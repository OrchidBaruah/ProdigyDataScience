# %% [markdown]
# **Task-02**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import plotly.express as px

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from warnings import filterwarnings

# %%
dataset1=pd.read_csv("/content/drive/MyDrive/titanic/test.csv")

# %%
dataset1.shape
# Out:
# (418, 11)

# %%
dataset1.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
dataset1.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
dataset1.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
dataset1.tail()
# Out:
#      PassengerId  Pclass                          Name     Sex   Age  SibSp  \
# 413         1305       3            Spector, Mr. Woolf    male   NaN      0
# 414         1306       1  Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415         1307       3  Saether, Mr. Simon Sivertsen    male  38.5      0
# 416         1308       3           Ware, Mr. Frederick    male   NaN      0
# 417         1309       3      Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked
# 413      0           A.5. 3236    8.0500   NaN        S
# 414      0            PC 17758  108.9000  C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0              359309    8.0500   NaN        S
# 417      1                2668   22.3583   NaN        C

# %%
dataset1.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
dataset1.info
# Out:
# <bound method DataFrame.info of      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
dataset1.count()
# Out:
# PassengerId    418
# Pclass         418
# Name           418
# Sex            418
# Age            332
# SibSp          418
# Parch          418
# Ticket         418
# Fare           417
# Cabin           91
# Embarked       418
# dtype: int64

# %%
dataset1[dataset1['Age']>30].head(10)
# Out:
#     PassengerId  Pclass                                               Name  \
# 0           892       3                                   Kelly, Mr. James
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2           894       2                          Myles, Mr. Thomas Francis
# 11          903       1                         Jones, Mr. Charles Cresson
# 13          905       2                               Howard, Mr. Benjamin
# 14          906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 16          908       2                                  Keane, Mr. Daniel
# 19          911       3              Assaf Khalil, Mrs. Mariana (Miriam")"
# 20          912       1                             Rothschild, Mr. Martin
# 24          916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
#
#        Sex   Age  SibSp  Parch       Ticket      Fare            Cabin  \
# ...

# %%
dataset1[dataset1['Age']>30].sort_values('Sex').head(10)
# Out:
#      PassengerId  Pclass                                               Name  \
# 208         1100       1                      Rosenbaum, Miss. Edith Louise
# 96           988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 100          992       1  Stengel, Mrs. Charles Emil Henry (Annie May Mo...
# 112         1004       1                           Evans, Miss. Edith Corse
# 114         1006       1             Straus, Mrs. Isidor (Rosalie Ida Blun)
# 350         1242       1       Greenfield, Mrs. Leo David (Blanche Strouse)
# 122         1014       1                    Schabert, Mrs. Paul (Emma Mock)
# 240         1132       1          Lindstrom, Mrs. Carl Johan (Sigrid Posse)
# 347         1239       3    Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 343         1235       1  Cardeza, Mrs. James Warburton Martinez (Charlo...
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
dataset1['Age'].nlargest(n=10)
# Out:
# 96     76.0
# 81     67.0
# 179    64.0
# 236    64.0
# 305    64.0
# 13     63.0
# 114    63.0
# 2      62.0
# 142    61.0
# 193    61.0
# Name: Age, dtype: float64

# %%
sns.countplot(x='Pclass', data=dataset1)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x='Pclass', hue='Embarked',data=dataset1)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x='SibSp', data=dataset1)
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
dataset1['Age'].isnull().sum()
# Out:
# 86

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
l = ['C = Cherbourg', 'Q = Queenstown', 'S = Southampton']
s = [0.553571,0.389610,0.336957]
ax.pie(s, labels = l,autopct='%1.2f%%')
plt.show()

# %%
dataset1['Age']=dataset1['Age'].fillna(dataset1['Age'].median())
dataset1['Age'].isnull().sum()
# Out:
# 0

# %%
dataset1.replace({'Sex':{'male':0,'female':1}},inplace=True)

# %%
dataset1.replace({'Embarked':{'C':0, 'Q':1 ,'S':2}})
# Out:
#      PassengerId  Pclass                                          Name  Sex  \
# 0            892       3                              Kelly, Mr. James    0
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)    1
# 2            894       2                     Myles, Mr. Thomas Francis    0
# 3            895       3                              Wirz, Mr. Albert    0
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1
# ..           ...     ...                                           ...  ...
# 413         1305       3                            Spector, Mr. Woolf    0
# 414         1306       1                  Oliva y Ocana, Dona. Fermina    1
# 415         1307       3                  Saether, Mr. Simon Sivertsen    0
# 416         1308       3                           Ware, Mr. Frederick    0
# 417         1309       3                      Peter, Master. Michael J    0
#
# ...

# %%
X=dataset1.drop(columns=['Name','Cabin'], axis=1)

# %%
X.head()
# Out:
#    PassengerId  Pclass  Sex   Age  SibSp  Parch   Ticket     Fare Embarked
# 0          892       3    0  34.5      0      0   330911   7.8292        Q
# 1          893       3    1  47.0      1      0   363272   7.0000        S
# 2          894       2    0  62.0      0      0   240276   9.6875        Q
# 3          895       3    0  27.0      0      0   315154   8.6625        S
# 4          896       3    1  22.0      1      1  3101298  12.2875        S

# %%
X['Age']=X['Age'].fillna(X['Age'].median())
X['Age'].isnull().sum()
# Out:
# 0

# %%
X=dataset1.drop(columns=['PassengerId','Name','Ticket','Cabin','Embarked'],axis=1)
Y=dataset1['Embarked']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=42)
print(X_train.shape)
# Out:
# (292, 6)

# %%
print(X_test.shape)
# Out:
# (126, 6)
